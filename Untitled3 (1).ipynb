# %%
class myStack:
    # Constructor
    def __init__(self, cap):
        self.capacity = cap
        self.arr = [0] * self.capacity
        self.top = -1

    # Push operation
    def push(self, x):
        if self.top == self.capacity - 1:
            print("Stack Overflow")
            return
        self.top += 1
        self.arr[self.top] = x

    # Pop operation
    def pop(self):
        if self.top == -1:
            print("Stack Underflow")
            return -1
        val = self.arr[self.top]
        self.top -= 1
        return val

    # Peek operation
    def peek(self):
        if self.top == -1:
            print("Stack Empty")
            return -1
        return self.arr[self.top]

    # Check if stack is empty
    def isEmpty(self):
        return self.top == -1

    # Check if stack is full
    def isFull(self):
        return self.top == self.capacity - 1


# Get stack size from user
size = int(input("Enter the size of the stack: "))

# Create stack
st = myStack(size)

# Get number of elements
n = int(input("Enter the number of elements to push: "))

# Push elements
for i in range(n):
    x = int(input(f"Enter element {i+1}: "))
st.push(x)

# Pop one element
print("Popped:", st.pop())

# Display top element
print("Top element:", st.peek())

# Check if stack is empty
print("Is empty:", "Yes" if st.isEmpty() else "No")

# Check if stack is full
print("Is stack full:", "Yes" if st.isFull() else "No")
# Out:
# Enter the size of the stack:  4
# Enter the number of elements to push:  4
# Enter element 1:  10
# Enter element 2:  20
# Enter element 3:  30
# Enter element 4:  40
# Popped: 40
# Stack Empty
# Top element: -1
# Is empty: Yes
# Is stack full: No

# %%
#node structure
class Node:
    def __init__(self,x):
        self.data=x
        self.next=None

#stack implementation using linked list
class myStack:
    def __init__(self):
        self.top=None
        self.count=0

#push operation
    def push(self,x):
        temp=Node(x)
        temp.next=self.top
        self.top=temp
        self.count += 1

#pop operation
    def pop(self):
        if self.top is None:
            print("Stack Underflow")
            return -1
        temp=self.top
        self.top=self.top.next
        self.count -= 1
        return temp.data

#peek operation
    def peek(self):
        if self.top is None:
            print("Stack is empty")
            return -1
            return self.top.data

#check if stack is empty
    def isEmpty(self):
        return self.top is None

#size of stack
    def size(self):
        return self.count

st=myStack()
n=int(input("enter the number of element to push:"))
for i in range(n):
    x=int(input(f"enter elemen{i+1}"))
    st.push(x)
print("\nPooped element:",st.pop())
print("top element:",st.peek())

if st.isEmpty():
    print("stack is empty")
else:
    print("stack is full")

print("current size:",st.size())
# Out:
# enter the number of element to push: 4
# enter elemen1 2
# enter elemen2 3
# enter elemen3 4
# enter elemen4 5
# Pooped element: 5
# top element: None
# stack is full
# current size: 3
