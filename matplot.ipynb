# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[5,6,8,10,15]
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Line plot")
plt.plot(x,y)
plt.savefig("sample.png")
plt.show()

# %%
x=[101,102,103,104,105]
y=[70,80,99,85,45]
x1=[101,102,103,104,105]
y1=[75,81,90,66,55]
plt.xlabel("RollNO")
plt.ylabel("Marks")
plt.xlim(101,110)
plt.ylim(40,100)
plt.title("Student Performance")
plt.plot(x,y,label="line-1",color="blue",linestyle="dotted",linewidth=2,marker='o',markerfacecolor='red',markersize=10)
plt.plot(x1,y1,label="line-2",color="yellow",linestyle="solid",linewidth=3,marker='*',markerfacecolor='green',markersize=14)
plt.legend()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("C:/Users/Ibscai08.DGVC-MCA/iris.csv")
x=df["speal_length"]
y=df["speal_width"]
plt.xlabel("length")
plt.ylabel("width")
plt.title("iris")
plt.plot(x,y,color="black",linestyle="dotted",linewidth=2,marker='*',markerfacecolor='red',markersize=10)

plt.show()

# %%
import matplotlib.pyplot as plt

# %%
student=["A","B","C","D","E"]
marks=[50,70,66,89,45]
plt.bar(student,marks,label="bar",color="red",width=0.4,edgecolor="black")
plt.legend()
plt.title("Student Marks in CIA")
plt.xlabel("student")
plt.ylabel("marks")
plt.show()

# %%
hours = [5,4,3,2,1,2,3,4,5,6,7,8,9,8,7,6,5]
marks = [1,2,4,6,8,9,8,7,6,7,8,9,8,6,4,2,1]
plt.scatter(hours, marks, color="red", marker="*", s=420, label="Heart")

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("C:/Users/Ibscai08.DGVC-MCA/iris.csv")
x=df["speal_length"]
y=df["speal_width"]
plt.scatter(x, y, color="blue", marker="o", s=20, label="iris")

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("C:/Users/Ibscai08.DGVC-MCA/iris.csv")
x=df["speal_length"]
y=df["speal_width"]
plt.bar(x,y,label="Iris",color="red",width=0.01,edgecolor="black")
plt.legend()
plt.xlabel("speal.length")
plt.ylabel("speal.width")
plt.title("Iris")
plt.show()

# %%
plt.hist(df['speal_length'])
# Out:
# (array([ 9., 22., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
import pandas as pd
mk=pd.Series(marks)
mk
# Out:
# 0     1
# 1     2
# 2     4
# 3     6
# 4     8
# 5     9
# 6     8
# 7     7
# 8     6
# 9     7
# 10    8
# 11    9
# 12    8
# 13    6
# 14    4
# 15    2
# 16    1
# dtype: int64

# %% [markdown]
# ## mk.plot(kind="density",color="red",linewidth=2,linestyle="--",label="marks")
# plt.legend()
# plt.grid(True)
# plt.show()

# %%
plt.subplot(2,2,1)
mk.plot(kind="density")
plt.subplot(2,2,2)
plt.hist(marks)
plt.subplot(2,2,3)
plt.scatter(hours,marks)
plt.subplot(2,2,4)
plt.bar(x,y)
# Out:
# <BarContainer object of 150 artists>

# %%
sns.boxplot(data=)
