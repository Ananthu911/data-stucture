# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/Ibscai08.DGVC-MCA/iris.csv")
df.head()
# Out:
#    speal_length  speal_width  pedal_length  pedal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           NaN          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.isnull()
# Out:
#      speal_length  speal_width  pedal_length  pedal_width  class
# 0           False        False         False        False  False
# 1            True        False         False        False  False
# 2           False        False         False        False  False
# 3           False        False         False        False  False
# 4           False        False         False        False  False
# ..            ...          ...           ...          ...    ...
# 145         False        False         False        False  False
# 146         False        False         False        False  False
# 147         False        False         False        False  False
# 148         False        False         False        False  False
# 149         False        False         False        False  False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# speal_length    1
# speal_width     2
# pedal_length    1
# pedal_width     3
# class           0
# dtype: int64

# %%
df['speal_width']=df['speal_width'].fillna(0.2)

# %%
df.isnull().sum()
# Out:
# speal_length    1
# speal_width     0
# pedal_length    1
# pedal_width     3
# class           0
# dtype: int64

# %%
mn=df["speal_length"].mean()
mn
# Out:
# 5.8496644295302005

# %%
df["speal_length"]=df["speal_length"].fillna(mn)

# %%
df.isnull().sum()
# Out:
# speal_length    0
# speal_width     0
# pedal_length    1
# pedal_width     3
# class           0
# dtype: int64

# %%
ma=df["pedal_length"].mode()
ma
# Out:
# 0    1.5
# Name: pedal_length, dtype: float64

# %%
df["pedal_length"]=df["pedal_length"].fillna(ma)

# %%
df.isnull().sum()
# Out:
# speal_length    0
# speal_width     0
# pedal_length    1
# pedal_width     3
# class           0
# dtype: int64

# %%
mb=df["pedal_width"].median()
mb
# Out:
# 1.3

# %%
df["pedal_width"]=df["pedal_width"].fillna(mb)

# %%
df.isnull().sum()
# Out:
# speal_length    0
# speal_width     0
# pedal_length    1
# pedal_width     0
# class           0
# dtype: int64

# %%
df['pedal_width'].isnull().sum()
# Out:
# 0

# %%
df=df.fillna(mb)
df.isnull().sum()
# Out:
# speal_length    0
# speal_width     0
# pedal_length    0
# pedal_width     0
# class           0
# dtype: int64

# %%
import numpy as np
df.replace(' ',np.nan)
# Out:
#      speal_length  speal_width  pedal_length  pedal_width           class
# 0        5.100000          3.5           1.4          0.2     Iris-setosa
# 1        5.849664          3.0           1.4          0.2     Iris-setosa
# 2        4.700000          3.2           1.3          0.2     Iris-setosa
# 3        4.600000          3.1           1.5          0.2     Iris-setosa
# 4        5.000000          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145      6.700000          3.0           5.2          2.3  Iris-virginica
# 146      6.300000          2.5           5.0          1.9  Iris-virginica
# 147      6.500000          3.0           5.2          2.0  Iris-virginica
# 148      6.200000          3.4           5.4          2.3  Iris-virginica
# 149      5.900000          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df=pd.read_csv("C:/Users/Ibscai08.DGVC-MCA/heart.csv")
df.head()
# Out:
#    number  sub  sbu_second  value  values zero  thid    tum
# 0      28    1           2  130.0   132.0    0   2.0  185.0
# 1      29    1           2  120.0   243.0    0   0.0  160.0
# 2      29    1           2  140.0     NaN    0   0.0  170.0
# 3      30    0           1  170.0   237.0    0   1.0  170.0
# 4      31    0           2  100.0   219.0    0   1.0  150.0

# %%
df.isnull()
# Out:
#      number    sub  sbu_second  value  values   zero   thid    tum
# 0     False  False       False  False   False  False  False  False
# 1     False  False       False  False   False  False  False  False
# 2     False  False       False  False    True  False  False  False
# 3     False  False       False  False   False  False  False  False
# 4     False  False       False  False   False  False  False  False
# ..      ...    ...         ...    ...     ...    ...    ...    ...
# 289   False  False       False  False   False  False  False  False
# 290   False  False       False  False   False  False  False  False
# 291   False  False       False  False   False  False  False  False
# 292   False  False       False  False   False  False  False  False
# 293   False  False       False  False   False  False  False  False
#
# [294 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# number         0
# sub            0
# sbu_second     0
# value          1
# values        23
# zero           7
# thid           1
# tum            1
# dtype: int64

# %%
df['value']=df['value'].fillna(0.2)

# %%
df.isnull().sum()
# Out:
# number         0
# sub            0
# sbu_second     0
# value          0
# values        23
# zero           7
# thid           1
# tum            1
# dtype: int64

# %%
mn=df["values"].mean()
mn
# Out:
# 250.84870848708488

# %%
df["values"]=df["values"].fillna(mn)

# %%
df.isnull().sum()
# Out:
# number        0
# sub           0
# sbu_second    0
# value         0
# values        0
# zero          7
# thid          1
# tum           1
# dtype: int64

# %%
df['zero']=df['zero'].fillna(0)

# %%
df.isnull().sum()
# Out:
# number        0
# sub           0
# sbu_second    0
# value         0
# values        0
# zero          0
# thid          1
# tum           1
# dtype: int64

# %%
mb=df["thid"].median()
mb
# Out:
# 0.0

# %%
df["thid"]=df["thid"].fillna(mb)

# %%
df.isnull().sum()
# Out:
# number        0
# sub           0
# sbu_second    0
# value         0
# values        0
# zero          0
# thid          0
# tum           1
# dtype: int64

# %%
df["tum"]=df["tum"].ffill()

# %%
df.isnull().sum()
# Out:
# number        0
# sub           0
# sbu_second    0
# value         0
# values        0
# zero          0
# thid          0
# tum           0
# dtype: int64

# %%
sns.boxplot(data=df,x="values",y="zero",legend=False)
# Out:
# <Axes: xlabel='values', ylabel='zero'>

# %%
df1=df.select_dtypes(include=['number'])
sns.heatmap(df1.corr(),annot=True,cmap="Greens")
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df,x="number",y="value",hue="tum")
# Out:
# <Axes: xlabel='number', ylabel='value'>
